# %% [markdown]
# #                          *DATA CLEANING CHALLENGE VOLUME 01*
#
# ### THE CHALLENGE HAS TO DO WITH CLEANING A  VERY DIRTY DATA SET GOTTEN FROM KAGGLE, USING WHATEVER DATA CLEANING TOOL OF  CHOICE AND I WILL BE USING PYTHON PROGRAMMING LANGUAGE TO CLEAN THIS DATA SET EXTENSIVELY FOR FUTHER ANALYTIC USE
# # THIS DATA IS CLEANED BY *GABRIEL STEVEN* A.K.A BLUEMAGIKSGO
# ### NOTE: THIS PROJECT TOOK FIVE DAYS TO CLEAN.

# %% [markdown]
# ## THE DESCRIPTION OF EACH COLUMNS WILL BE AVAILABLE IN A SEPERATE PDF

# %%
import pandas as pd

# %%
df = pd.read_csv("fifa21 raw data v2.csv", low_memory = False)
df.head(2)
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
#
#    POT                  Club     Contract   Positions Height Weight  \
# 0   93  \n\n\n\nFC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg
# 1   92      \n\n\n\nJuventus  2018 ~ 2022      ST, LW  187cm   83kg
#
#   Preferred Foot  BOV Best Position        Joined Loan Date End    Value  \
# 0           Left   93            RW   Jul 1, 2004           NaN  €103.5M
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
# ...

# %% [markdown]
# ## Drop 'photoUrl' column since playerUrl will contain such information.

# %%
df.drop("photoUrl", axis = 1, inplace = True)

# %%
df.head(2)
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
#
#    POT                  Club     Contract   Positions Height Weight  \
# 0   93  \n\n\n\nFC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg
# 1   92      \n\n\n\nJuventus  2018 ~ 2022      ST, LW  187cm   83kg
#
#   Preferred Foot  BOV Best Position        Joined Loan Date End    Value  \
# 0           Left   93            RW   Jul 1, 2004           NaN  €103.5M
# 1          Right   92            ST  Jul 10, 2018           NaN     €63M
#
#     Wage Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# ...

# %%
df.shape
# Out:
# (18979, 76)

# %% [markdown]
# ## Capitalize the first letter of the 'playerUrl' column

# %%
df.rename(columns={"playerUrl":"PlayerUrl"}, inplace = True)

# %%
df.head(2)
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
#
#    POT                  Club     Contract   Positions Height Weight  \
# 0   93  \n\n\n\nFC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg
# 1   92      \n\n\n\nJuventus  2018 ~ 2022      ST, LW  187cm   83kg
#
#   Preferred Foot  BOV Best Position        Joined Loan Date End    Value  \
# 0           Left   93            RW   Jul 1, 2004           NaN  €103.5M
# 1          Right   92            ST  Jul 10, 2018           NaN     €63M
#
#     Wage Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# ...

# %% [markdown]
# ## Change column 'LongName' to 'FullName' and '↓OVA' to OverallRating

# %%
df.rename(columns={"LongName":"FullName"}, inplace = True)

# %%
df.head(2)
# Out:
#        ID               Name                      FullName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
#
#    POT                  Club     Contract   Positions Height Weight  \
# 0   93  \n\n\n\nFC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg
# 1   92      \n\n\n\nJuventus  2018 ~ 2022      ST, LW  187cm   83kg
#
#   Preferred Foot  BOV Best Position        Joined Loan Date End    Value  \
# 0           Left   93            RW   Jul 1, 2004           NaN  €103.5M
# 1          Right   92            ST  Jul 10, 2018           NaN     €63M
#
#     Wage Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# ...

# %%
df.rename(columns={"↓OVA":"OverallRating"}, inplace = True)

# %% [markdown]
# ## Expand the columns to access all columns for examination and cleaning

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(2)
# Out:
#        ID               Name                      FullName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality  Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35
#
#    OverallRating  POT                  Club     Contract   Positions Height  \
# 0             93   93  \n\n\n\nFC Barcelona  2004 ~ 2021  RW, ST, CF  170cm
# 1             92   92      \n\n\n\nJuventus  2018 ~ 2022      ST, LW  187cm
#
#   Weight Preferred Foot  BOV Best Position        Joined Loan Date End  \
# 0   72kg           Left   93            RW   Jul 1, 2004           NaN
# 1   83kg          Right   92            ST  Jul 10, 2018           NaN
#
#      Value   Wage Release Clause  Attacking  Crossing  Finishing  \
# ...

# %% [markdown]
# ## Remove the '\n\n\n\n' in the club column

# %%
df.Club
# Out:
# 0               \n\n\n\nFC Barcelona
# 1                   \n\n\n\nJuventus
# 2            \n\n\n\nAtlético Madrid
# 3            \n\n\n\nManchester City
# 4        \n\n\n\nParis Saint-Germain
#                     ...
# 18974             \n\n\n\nWuhan Zall
# 18975        \n\n\n\nOldham Athletic
# 18976             \n\n\n\nDerry City
# 18977       \n\n\n\nDalian YiFang FC
# 18978       \n\n\n\nDalian YiFang FC
# Name: Club, Length: 18979, dtype: object

# %%
df.Club = df['Club'].str[4:].replace()

# %%
df.Club
# Out:
# 0               FC Barcelona
# 1                   Juventus
# 2            Atlético Madrid
# 3            Manchester City
# 4        Paris Saint-Germain
#                 ...
# 18974             Wuhan Zall
# 18975        Oldham Athletic
# 18976             Derry City
# 18977       Dalian YiFang FC
# 18978       Dalian YiFang FC
# Name: Club, Length: 18979, dtype: object

# %% [markdown]
# ## Examine the dataframe again

# %%
df.head(2)
# Out:
#        ID               Name                      FullName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality  Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35
#
#    OverallRating  POT          Club     Contract   Positions Height Weight  \
# 0             93   93  FC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg
# 1             92   92      Juventus  2018 ~ 2022      ST, LW  187cm   83kg
#
#   Preferred Foot  BOV Best Position        Joined Loan Date End    Value  \
# 0           Left   93            RW   Jul 1, 2004           NaN  €103.5M
# 1          Right   92            ST  Jul 10, 2018           NaN     €63M
#
#     Wage Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# ...

# %% [markdown]
# ## With df['Loan Date End'] having 17966 null values out of the 18979 values of the dataframe, it is obvious the column is less informative and important so we drop such unnecessary column to make the data frame neater

# %%
df.drop("Loan Date End", axis = 1, inplace = True)

# %%
df.head(2)
# Out:
#        ID               Name                      FullName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality  Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35
#
#    OverallRating  POT          Club     Contract   Positions Height Weight  \
# 0             93   93  FC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg
# 1             92   92      Juventus  2018 ~ 2022      ST, LW  187cm   83kg
#
#   Preferred Foot  BOV Best Position        Joined    Value   Wage  \
# 0           Left   93            RW   Jul 1, 2004  €103.5M  €560K
# 1          Right   92            ST  Jul 10, 2018     €63M  €220K
#
#   Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# 0        €138.4M        429        85         95                70
# ...

# %% [markdown]
# ## Change the '~' in df['Contract'] to '-' which is the standard way to seperate

# %%
df['Contract'] = df['Contract'].str.replace("~", "-")

# %%
df.head(2)
# Out:
#        ID               Name                      FullName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality  Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35
#
#    OverallRating  POT          Club     Contract   Positions Height Weight  \
# 0             93   93  FC Barcelona  2004 - 2021  RW, ST, CF  170cm   72kg
# 1             92   92      Juventus  2018 - 2022      ST, LW  187cm   83kg
#
#   Preferred Foot  BOV Best Position        Joined    Value   Wage  \
# 0           Left   93            RW   Jul 1, 2004  €103.5M  €560K
# 1          Right   92            ST  Jul 10, 2018     €63M  €220K
#
#   Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# 0        €138.4M        429        85         95                70
# ...

# %% [markdown]
# ## Also in df['Positions'], the seperator is a comma, we have to change it to a pipe to make the df clean

# %%
df.Positions = df['Positions'].str.replace(",", "|")

# %%
df.head(2)
# Out:
#        ID               Name                      FullName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality  Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35
#
#    OverallRating  POT          Club     Contract   Positions Height Weight  \
# 0             93   93  FC Barcelona  2004 - 2021  RW| ST| CF  170cm   72kg
# 1             92   92      Juventus  2018 - 2022      ST| LW  187cm   83kg
#
#   Preferred Foot  BOV Best Position        Joined    Value   Wage  \
# 0           Left   93            RW   Jul 1, 2004  €103.5M  €560K
# 1          Right   92            ST  Jul 10, 2018     €63M  €220K
#
#   Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# 0        €138.4M        429        85         95                70
# ...

# %% [markdown]
# ## Examine the columns that still have null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 75 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   FullName          18979 non-null  object
#  3   PlayerUrl         18979 non-null  object
#  4   Nationality       18979 non-null  object
#  5   Age               18979 non-null  int64
#  6   OverallRating     18979 non-null  int64
#  7   POT               18979 non-null  int64
#  8   Club              18979 non-null  object
#  9   Contract          18979 non-null  object
#  10  Positions         18979 non-null  object
#  11  Height            18979 non-null  object
#  12  Weight            18979 non-null  object
#  13  Preferred Foot    18979 non-null  object
#  14  BOV               18979 non-null  int64
#  15  Best Position     18979 non-null  object
# ...

# %% [markdown]
# ## From the infomation gotten from the .info() above, we can see that the Hits still have about 2595 null values because 16384 - 18979 = 2595.

# %%
df.Hits.isnull().sum()
# Out:
# 2595

# %% [markdown]
# ## Get the missen Hits values

# %% [markdown]
# ## Since the Hits column entails the number of times the players  profile has been viewed on the website, with the column being set to NaN, we have the assume it means their profile has not been viewed on the site, hence we set the value to 0

# %%
df.Hits = df.Hits.fillna('0')

# %%
df.Hits.isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 75 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   FullName          18979 non-null  object
#  3   PlayerUrl         18979 non-null  object
#  4   Nationality       18979 non-null  object
#  5   Age               18979 non-null  int64
#  6   OverallRating     18979 non-null  int64
#  7   POT               18979 non-null  int64
#  8   Club              18979 non-null  object
#  9   Contract          18979 non-null  object
#  10  Positions         18979 non-null  object
#  11  Height            18979 non-null  object
#  12  Weight            18979 non-null  object
#  13  Preferred Foot    18979 non-null  object
#  14  BOV               18979 non-null  int64
#  15  Best Position     18979 non-null  object
# ...

# %%
#After changeing the null values in Hits to 0, using .info(), we can see that there are no longer any null values and all we have to do is know if there will be any other futher cleaning to do

# %%
df.Hits.unique()
# Out:
# array(['771', '562', '150', '207', '595', '248', '246', '120', '1.6K',
#        '130', '321', '189', '175', '96', '118', '216', '212', '154',
#        '205', '202', '339', '408', '103', '332', '86', '173', '161',
#        '396', '1.1K', '433', '242', '206', '177', '1.5K', '198', '459',
#        '117', '119', '209', '84', '187', '165', '203', '65', '336', '126',
#        '313', '124', '145', '538', '182', '101', '45', '377', '99', '194',
#        '403', '414', '593', '374', '245', '3.2K', '266', '299', '309',
#        '215', '265', '211', '112', '337', '70', '159', '688', '116', '63',
#        '144', '123', '71', '224', '113', '168', '61', '89', '137', '278',
#        '75', '148', '176', '197', '264', '214', '247', '402', '440',
#        '1.7K', '2.3K', '171', '320', '657', '87', '259', '200', '255',
#        '253', '196', '60', '97', '85', '169', '256', '132', '239', '166',
#        '121', '109', '32', '46', '122', '48', '527', '199', '282', '51',
# ...

# %% [markdown]
# ## some values in the Hit columns contain 'K', so we change those values to thousand

# %%
result = df[df['Hits'].str.contains('K')]

# %%
result.head(2)
# Out:
#         ID       Name       FullName  \
# 8   231747  K. Mbappé  Kylian Mbappé
# 29  233049  J. Sancho   Jadon Sancho
#
#                                             PlayerUrl Nationality  Age  \
# 8   http://sofifa.com/player/231747/kylian-mbappe/...      France   21
# 29  http://sofifa.com/player/233049/jadon-sancho/2...     England   20
#
#     OverallRating  POT                 Club     Contract    Positions Height  \
# 8              90   95  Paris Saint-Germain  2018 - 2022   ST| LW| RW  178cm
# 29             87   93    Borussia Dortmund  2017 - 2023  RM| LM| CAM  180cm
#
#    Weight Preferred Foot  BOV Best Position        Joined    Value   Wage  \
# 8    73kg          Right   91            ST   Jul 1, 2018  €185.5M  €160K
# 29   76kg          Right   89           CAM  Aug 31, 2017    €124M   €82K
#
#    Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# 8         €203.1M        408        78         91                73
# ...

# %%
# Remove the "." and replace "K" to 00

# %%
remove_ch = lambda x: x.replace('.', '').replace('K', '00') if isinstance(x, str) else x

# %%
result.Hits = result.Hits.apply(remove_ch)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\1333713077.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result.Hits = result.Hits.apply(remove_ch)

# %%
result.Hits.reset_index()
# Out:
#     index  Hits
# 0       8  1600
# 1      29  1100
# 2      34  1500
# 3      68  3200
# 4     105  1700
# 5     106  2300
# 6     147  1900
# 7     416   200
# 8     544  1100
# 9     687  1300
# 10    690   300
# 11   1011  1400
# 12   1265  2800
# 13   1380  1800
# 14   1818  1300
# 15   2579  8400
# 16   2757  1100
# 17   3791  4300
# 18   3893  1600
# 19   4091  1200
# 20   4096  1300
# 21   4800  2300
# 22   5266  1800
# 23   6159  1100
# 24   6235  1400
# 25   8116   100
# 26   8401  2500
# 27  15819   600

# %% [markdown]
# ### Some of the thousands came out to be hundred so we change those hundreds to thousands

# %%
index_list = [416,690,8116,15819]

# %%
rows_to_change = result.loc[index_list]

# %%
xx = lambda x: x.replace('00', '000')

# %%
rows_to_change['Hits'] = rows_to_change['Hits'].apply(xx)

# %% [markdown]
# ### After updating the hundreds to thousands, update the output to the result variable which hold values that were formerly 'k's

# %%
result.update(rows_to_change)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\1119982295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result.update(rows_to_change)
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\1119982295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result.update(rows_to_change)
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\1119982295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
result.head(2)
# Out:
#           ID       Name       FullName  \
# 8   231747.0  K. Mbappé  Kylian Mbappé
# 29  233049.0  J. Sancho   Jadon Sancho
#
#                                             PlayerUrl Nationality   Age  \
# 8   http://sofifa.com/player/231747/kylian-mbappe/...      France  21.0
# 29  http://sofifa.com/player/233049/jadon-sancho/2...     England  20.0
#
#     OverallRating   POT                 Club     Contract    Positions Height  \
# 8            90.0  95.0  Paris Saint-Germain  2018 - 2022   ST| LW| RW  178cm
# 29           87.0  93.0    Borussia Dortmund  2017 - 2023  RM| LM| CAM  180cm
#
#    Weight Preferred Foot   BOV Best Position        Joined    Value   Wage  \
# 8    73kg          Right  91.0            ST   Jul 1, 2018  €185.5M  €160K
# 29   76kg          Right  89.0           CAM  Aug 31, 2017    €124M   €82K
#
#    Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# 8         €203.1M      408.0      78.0       91.0              73.0
# ...

# %%
df.update(result)

# %%
df.Hits = df.Hits.astype("int64")

# %% [markdown]
# ## Some columns have '★' in them so we have to delete that character in the columns to make the data frame more professional

# %%
replaced_chr = lambda x: x.replace('★',"")

# %%
df.IR = df.IR.apply(replaced_chr)
df.SM = df.SM.apply(replaced_chr)

# %%
df['W/F'] = df['W/F'].apply(replaced_chr)

# %%
df.head()
# Out:
#          ID               Name                      FullName  \
# 0  158023.0           L. Messi                  Lionel Messi
# 1   20801.0  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389.0           J. Oblak                     Jan Oblak
# 3  192985.0       K. De Bruyne               Kevin De Bruyne
# 4  190871.0          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            PlayerUrl Nationality   Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  33.0
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal  35.0
# 2  http://sofifa.com/player/200389/jan-oblak/210006/    Slovenia  27.0
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium  29.0
# 4  http://sofifa.com/player/190871/neymar-da-silv...      Brazil  28.0
#
#    OverallRating   POT                 Club     Contract   Positions Height  \
# 0           93.0  93.0         FC Barcelona  2004 - 2021  RW| ST| CF  170cm
# ...

# %% [markdown]
# ## Change the Joined column to a datetime datatype

# %%
df['Joined'] = pd.to_datetime(df['Joined'])

# %%
df['Joined']
# Out:
# 0       2004-07-01
# 1       2018-07-10
# 2       2014-07-16
# 3       2015-08-30
# 4       2017-08-03
#            ...
# 18974   2018-07-13
# 18975   2020-08-01
# 18976   2019-03-08
# 18977   2020-09-22
# 18978   2019-07-29
# Name: Joined, Length: 18979, dtype: datetime64[ns]

# %%
df.head(2)
# Out:
#          ID               Name                      FullName  \
# 0  158023.0           L. Messi                  Lionel Messi
# 1   20801.0  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality   Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  33.0
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal  35.0
#
#    OverallRating   POT          Club     Contract   Positions Height Weight  \
# 0           93.0  93.0  FC Barcelona  2004 - 2021  RW| ST| CF  170cm   72kg
# 1           92.0  92.0      Juventus  2018 - 2022      ST| LW  187cm   83kg
#
#   Preferred Foot   BOV Best Position     Joined    Value   Wage  \
# 0           Left  93.0            RW 2004-07-01  €103.5M  €560K
# 1          Right  92.0            ST 2018-07-10     €63M  €220K
#
#   Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# ...

# %% [markdown]
# ## The age column is in a float data type, change it to an integer instead because age cannot be in a float data type

# %%
df.Age = df['Age'].astype("int32")

# %% [markdown]
# ## Work on the height and weight column

# %% [markdown]
# # Height Cleaning

# %%
df.Height.unique()
# Out:
# array(['170cm', '187cm', '188cm', '181cm', '175cm', '184cm', '191cm',
#        '178cm', '193cm', '185cm', '199cm', '173cm', '168cm', '176cm',
#        '177cm', '183cm', '180cm', '189cm', '179cm', '195cm', '172cm',
#        '182cm', '186cm', '192cm', '165cm', '194cm', '167cm', '196cm',
#        '163cm', '190cm', '174cm', '169cm', '171cm', '197cm', '200cm',
#        '166cm', '6\'2"', '164cm', '198cm', '6\'3"', '6\'5"', '5\'11"',
#        '6\'4"', '6\'1"', '6\'0"', '5\'10"', '5\'9"', '5\'6"', '5\'7"',
#        '5\'4"', '201cm', '158cm', '162cm', '161cm', '160cm', '203cm',
#        '157cm', '156cm', '202cm', '159cm', '206cm', '155cm'], dtype=object)

# %%
#There are some feet in the height column that is supposed to be in centimeter, we have to get those values that are in feet
feet = df[df['Height'].str.contains('"')]

# %%
feet
# Out:
#            ID              Name                          FullName  \
# 793  110677.0              Moyá           Miguel Ángel Moyá Rumbo
# 847  166706.0         M. Škrtel                     Martin Škrtel
# 848  189068.0           B. Dost                          Bas Dost
# 860  198031.0   Sérgio Oliveira  Sérgio Miguel Relvas de Oliveira
# 861  190243.0           M. Hitz                       Marwin Hitz
# 862  194222.0         Laguardia         Víctor Laguardia Cisneros
# 863  194209.0       Y. El Arabi                  Youssef El Arabi
# 864  193601.0       G. Pezzella                   Germán Pezzella
# 865  193352.0      R. Rodríguez                 Ricardo Rodríguez
# 866  193152.0          Herrerín              Iago Herrerín Buisán
# 867  192546.0        E. Stevens                      Enda Stevens
# 868  192123.0           C. Wood                        Chris Wood
# 869  192086.0        A. Kokorin                  Alexandr Kokorin
# ...

# %%
# Remove the characters that makes the values a feet 
replace = lambda x: x.replace("'",".").replace('"',' ')

# %%
feet['Height'] = feet['Height'].apply(replace).astype('float')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\2889031555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feet['Height'] = feet['Height'].apply(replace).astype('float')

# %%
#Using the lambda function, change the feets to centimeter
rp = lambda x: x * 30.48
feet['Height'] = feet['Height'].apply(rp)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\3708782053.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feet['Height'] = feet['Height'].apply(rp)

# %%
feet['Height'] = feet['Height'].astype('int')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\1208867059.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feet['Height'] = feet['Height'].astype('int')

# %%
feet
# Out:
#            ID              Name                          FullName  \
# 793  110677.0              Moyá           Miguel Ángel Moyá Rumbo
# 847  166706.0         M. Škrtel                     Martin Škrtel
# 848  189068.0           B. Dost                          Bas Dost
# 860  198031.0   Sérgio Oliveira  Sérgio Miguel Relvas de Oliveira
# 861  190243.0           M. Hitz                       Marwin Hitz
# 862  194222.0         Laguardia         Víctor Laguardia Cisneros
# 863  194209.0       Y. El Arabi                  Youssef El Arabi
# 864  193601.0       G. Pezzella                   Germán Pezzella
# 865  193352.0      R. Rodríguez                 Ricardo Rodríguez
# 866  193152.0          Herrerín              Iago Herrerín Buisán
# 867  192546.0        E. Stevens                      Enda Stevens
# 868  192123.0           C. Wood                        Chris Wood
# 869  192086.0        A. Kokorin                  Alexandr Kokorin
# ...

# %%
feet['Height'] = feet['Height'].astype('str')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\137004716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feet['Height'] = feet['Height'].astype('str')

# %%
df.update(feet)

# %%
df.Height.unique()
# Out:
# array(['170cm', '187cm', '188cm', '181cm', '175cm', '184cm', '191cm',
#        '178cm', '193cm', '185cm', '199cm', '173cm', '168cm', '176cm',
#        '177cm', '183cm', '180cm', '189cm', '179cm', '195cm', '172cm',
#        '182cm', '186cm', '192cm', '165cm', '194cm', '167cm', '196cm',
#        '163cm', '190cm', '174cm', '169cm', '171cm', '197cm', '200cm',
#        '166cm', '188', '164cm', '198cm', '192', '198', '155', '195',
#        '185', '182', '179', '170', '173', '164', '201cm', '158cm',
#        '162cm', '161cm', '160cm', '203cm', '157cm', '156cm', '202cm',
#        '159cm', '206cm', '155cm'], dtype=object)

# %% [markdown]
# ## Remove the 'cm' from the whole column to turn the column to an int datatype

# %%
cm = df[df['Height'].str.contains('cm')]

# %%
cm_rep = lambda x: x.replace('cm'," ")

# %%
cm.Height = cm.Height.apply(cm_rep)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\3135377847.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cm.Height = cm.Height.apply(cm_rep)

# %%
df.update(cm)

# %%
df.Height.unique()
# Out:
# array(['170 ', '187 ', '188 ', '181 ', '175 ', '184 ', '191 ', '178 ',
#        '193 ', '185 ', '199 ', '173 ', '168 ', '176 ', '177 ', '183 ',
#        '180 ', '189 ', '179 ', '195 ', '172 ', '182 ', '186 ', '192 ',
#        '165 ', '194 ', '167 ', '196 ', '163 ', '190 ', '174 ', '169 ',
#        '171 ', '197 ', '200 ', '166 ', '188', '164 ', '198 ', '192',
#        '198', '155', '195', '185', '182', '179', '170', '173', '164',
#        '201 ', '158 ', '162 ', '161 ', '160 ', '203 ', '157 ', '156 ',
#        '202 ', '159 ', '206 ', '155 '], dtype=object)

# %% [markdown]
# ## Rename column Height to Height (cm)

# %%
df = df.rename(columns={'Height': 'Height(cm)'})

# %%
df.head(2)
# Out:
#          ID               Name                      FullName  \
# 0  158023.0           L. Messi                  Lionel Messi
# 1   20801.0  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality   Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  33.0
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal  35.0
#
#    OverallRating   POT          Club     Contract   Positions Height(cm)  \
# 0           93.0  93.0  FC Barcelona  2004 - 2021  RW| ST| CF       170
# 1           92.0  92.0      Juventus  2018 - 2022      ST| LW       187
#
#   Weight Preferred Foot   BOV Best Position     Joined    Value   Wage  \
# 0   72kg           Left  93.0            RW 2004-07-01  €103.5M  €560K
# 1   83kg          Right  92.0            ST 2018-07-10     €63M  €220K
#
#   Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# ...

# %%
df['Height(cm)'] = df['Height(cm)'].astype('int32')

# %%
df.head(2)
# Out:
#          ID               Name                      FullName  \
# 0  158023.0           L. Messi                  Lionel Messi
# 1   20801.0  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality   Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  33.0
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal  35.0
#
#    OverallRating   POT          Club     Contract   Positions  Height(cm)  \
# 0           93.0  93.0  FC Barcelona  2004 - 2021  RW| ST| CF         170
# 1           92.0  92.0      Juventus  2018 - 2022      ST| LW         187
#
#   Weight Preferred Foot   BOV Best Position     Joined    Value   Wage  \
# 0   72kg           Left  93.0            RW 2004-07-01  €103.5M  €560K
# 1   83kg          Right  92.0            ST 2018-07-10     €63M  €220K
#
#   Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# ...

# %% [markdown]
# ## Since the Height column has been changed to "cm", we have to work on the weight column

# %% [markdown]
# # Weight Cleaning

# %%
df.head(2)
# Out:
#          ID               Name                      FullName  \
# 0  158023.0           L. Messi                  Lionel Messi
# 1   20801.0  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality   Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  33.0
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal  35.0
#
#    OverallRating   POT          Club     Contract   Positions  Height(cm)  \
# 0           93.0  93.0  FC Barcelona  2004 - 2021  RW| ST| CF         170
# 1           92.0  92.0      Juventus  2018 - 2022      ST| LW         187
#
#   Weight Preferred Foot   BOV Best Position     Joined    Value   Wage  \
# 0   72kg           Left  93.0            RW 2004-07-01  €103.5M  €560K
# 1   83kg          Right  92.0            ST 2018-07-10     €63M  €220K
#
#   Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# ...

# %%
df.Weight.unique()
# Out:
# array(['72kg', '83kg', '87kg', '70kg', '68kg', '80kg', '71kg', '91kg',
#        '73kg', '85kg', '92kg', '69kg', '84kg', '96kg', '81kg', '82kg',
#        '75kg', '86kg', '89kg', '74kg', '76kg', '64kg', '78kg', '90kg',
#        '66kg', '60kg', '94kg', '79kg', '67kg', '65kg', '59kg', '61kg',
#        '93kg', '88kg', '97kg', '77kg', '62kg', '63kg', '95kg', '100kg',
#        '58kg', '183lbs', '179lbs', '172lbs', '196lbs', '176lbs', '185lbs',
#        '170lbs', '203lbs', '168lbs', '161lbs', '146lbs', '130lbs',
#        '190lbs', '174lbs', '148lbs', '165lbs', '159lbs', '192lbs',
#        '181lbs', '139lbs', '154lbs', '157lbs', '163lbs', '98kg', '103kg',
#        '99kg', '102kg', '56kg', '101kg', '57kg', '55kg', '104kg', '107kg',
#        '110kg', '53kg', '50kg', '54kg', '52kg'], dtype=object)

# %% [markdown]
# ## create a df for the weights measured in lbs

# %%
lbs = df[df['Weight'].str.contains('lbs')]

# %%
lbs
# Out:
#            ID              Name                          FullName  \
# 793  110677.0              Moyá           Miguel Ángel Moyá Rumbo
# 847  166706.0         M. Škrtel                     Martin Škrtel
# 848  189068.0           B. Dost                          Bas Dost
# 860  198031.0   Sérgio Oliveira  Sérgio Miguel Relvas de Oliveira
# 861  190243.0           M. Hitz                       Marwin Hitz
# 862  194222.0         Laguardia         Víctor Laguardia Cisneros
# 863  194209.0       Y. El Arabi                  Youssef El Arabi
# 864  193601.0       G. Pezzella                   Germán Pezzella
# 865  193352.0      R. Rodríguez                 Ricardo Rodríguez
# 866  193152.0          Herrerín              Iago Herrerín Buisán
# 867  192546.0        E. Stevens                      Enda Stevens
# 868  192123.0           C. Wood                        Chris Wood
# 869  192086.0        A. Kokorin                  Alexandr Kokorin
# ...

# %% [markdown]
# ## Remove the lbs

# %%
change = lambda x: x.replace("lbs"," ")

# %%
lbs.Weight = lbs.Weight.apply(change)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\2178442534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lbs.Weight = lbs.Weight.apply(change)

# %%
# change the values to float values so we can add it up to kilogram
lbs.Weight = lbs.Weight.astype(float)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\118644130.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lbs.Weight = lbs.Weight.astype(float)

# %%
# add up with the kg value to turn lbs to kilogram
lbs_to_kg = lambda x: x / 2.2046

# %%
lbs.Weight = lbs.Weight.apply(lbs_to_kg).astype('int')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\1356485647.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lbs.Weight = lbs.Weight.apply(lbs_to_kg).astype('int')

# %%
#change from 
lbs.Weight = lbs.Weight.astype('str')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\2085406940.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lbs.Weight = lbs.Weight.astype('str')

# %%
lbs
# Out:
#            ID              Name                          FullName  \
# 793  110677.0              Moyá           Miguel Ángel Moyá Rumbo
# 847  166706.0         M. Škrtel                     Martin Škrtel
# 848  189068.0           B. Dost                          Bas Dost
# 860  198031.0   Sérgio Oliveira  Sérgio Miguel Relvas de Oliveira
# 861  190243.0           M. Hitz                       Marwin Hitz
# 862  194222.0         Laguardia         Víctor Laguardia Cisneros
# 863  194209.0       Y. El Arabi                  Youssef El Arabi
# 864  193601.0       G. Pezzella                   Germán Pezzella
# 865  193352.0      R. Rodríguez                 Ricardo Rodríguez
# 866  193152.0          Herrerín              Iago Herrerín Buisán
# 867  192546.0        E. Stevens                      Enda Stevens
# 868  192123.0           C. Wood                        Chris Wood
# 869  192086.0        A. Kokorin                  Alexandr Kokorin
# ...

# %%
df.update(lbs)

# %%
df.Weight.unique()
# Out:
# array(['72kg', '83kg', '87kg', '70kg', '68kg', '80kg', '71kg', '91kg',
#        '73kg', '85kg', '92kg', '69kg', '84kg', '96kg', '81kg', '82kg',
#        '75kg', '86kg', '89kg', '74kg', '76kg', '64kg', '78kg', '90kg',
#        '66kg', '60kg', '94kg', '79kg', '67kg', '65kg', '59kg', '61kg',
#        '93kg', '88kg', '97kg', '77kg', '62kg', '63kg', '95kg', '100kg',
#        '58kg', '83', '81', '78', '88', '79', '77', '92', '76', '73', '66',
#        '58', '86', '67', '74', '72', '87', '82', '63', '69', '71', '98kg',
#        '103kg', '99kg', '102kg', '56kg', '101kg', '57kg', '55kg', '104kg',
#        '107kg', '110kg', '53kg', '50kg', '54kg', '52kg'], dtype=object)

# %%
kg = df[df.Weight.str.contains('kg')]
nkg = lambda x: x.replace('kg',' ')
kg.Weight = kg.Weight.apply(nkg)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\1105794794.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kg.Weight = kg.Weight.apply(nkg)

# %%
df.update(kg)

# %%
df.Weight.unique()
# Out:
# array(['72 ', '83 ', '87 ', '70 ', '68 ', '80 ', '71 ', '91 ', '73 ',
#        '85 ', '92 ', '69 ', '84 ', '96 ', '81 ', '82 ', '75 ', '86 ',
#        '89 ', '74 ', '76 ', '64 ', '78 ', '90 ', '66 ', '60 ', '94 ',
#        '79 ', '67 ', '65 ', '59 ', '61 ', '93 ', '88 ', '97 ', '77 ',
#        '62 ', '63 ', '95 ', '100 ', '58 ', '83', '81', '78', '88', '79',
#        '77', '92', '76', '73', '66', '58', '86', '67', '74', '72', '87',
#        '82', '63', '69', '71', '98 ', '103 ', '99 ', '102 ', '56 ',
#        '101 ', '57 ', '55 ', '104 ', '107 ', '110 ', '53 ', '50 ', '54 ',
#        '52 '], dtype=object)

# %% [markdown]
# ## Rename the weight column to Weight (kg)

# %%
df = df.rename(columns={'Weight': 'Weight(kg)'})

# %%
df.head(2)
# Out:
#          ID               Name                      FullName  \
# 0  158023.0           L. Messi                  Lionel Messi
# 1   20801.0  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality   Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  33.0
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal  35.0
#
#    OverallRating   POT          Club     Contract   Positions  Height(cm)  \
# 0           93.0  93.0  FC Barcelona  2004 - 2021  RW| ST| CF       170.0
# 1           92.0  92.0      Juventus  2018 - 2022      ST| LW       187.0
#
#   Weight(kg) Preferred Foot   BOV Best Position     Joined    Value   Wage  \
# 0        72            Left  93.0            RW 2004-07-01  €103.5M  €560K
# 1        83           Right  92.0            ST 2018-07-10     €63M  €220K
#
#   Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# ...

# %%
df['Weight(kg)'] = df['Weight(kg)'].astype('int')

# %%
df.head(2)
# Out:
#          ID               Name                      FullName  \
# 0  158023.0           L. Messi                  Lionel Messi
# 1   20801.0  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality   Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  33.0
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal  35.0
#
#    OverallRating   POT          Club     Contract   Positions  Height(cm)  \
# 0           93.0  93.0  FC Barcelona  2004 - 2021  RW| ST| CF       170.0
# 1           92.0  92.0      Juventus  2018 - 2022      ST| LW       187.0
#
#    Weight(kg) Preferred Foot   BOV Best Position     Joined    Value   Wage  \
# 0          72           Left  93.0            RW 2004-07-01  €103.5M  €560K
# 1          83          Right  92.0            ST 2018-07-10     €63M  €220K
#
#   Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# ...

# %%
df['Height(cm)'] = df['Height(cm)'].astype('int')
df['Weight(kg)'] = df['Weight(kg)'].astype('int')
df.Age = df.Age.astype('int')

# %%
df.head(2)
# Out:
#          ID               Name                      FullName  \
# 0  158023.0           L. Messi                  Lionel Messi
# 1   20801.0  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality  Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35
#
#    OverallRating   POT          Club     Contract   Positions  Height(cm)  \
# 0           93.0  93.0  FC Barcelona  2004 - 2021  RW| ST| CF         170
# 1           92.0  92.0      Juventus  2018 - 2022      ST| LW         187
#
#    Weight(kg) Preferred Foot   BOV Best Position     Joined    Value   Wage  \
# 0          72           Left  93.0            RW 2004-07-01  €103.5M  €560K
# 1          83          Right  92.0            ST 2018-07-10     €63M  €220K
#
#   Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# ...

# %% [markdown]
# ## Work on the Release Clause,Wage and Value column by removing and moving the currency sign to the column title and also the M and K values should be numerically specified

# %%
df['Release Clause'] = df['Release Clause'].str[1:].replace()
df['Wage'] = df['Wage'].str[1:].replace()
df['Value'] = df['Value'].str[1:].replace()

# %%
df.head(2)
# Out:
#          ID               Name                      FullName  \
# 0  158023.0           L. Messi                  Lionel Messi
# 1   20801.0  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality  Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35
#
#    OverallRating   POT          Club     Contract   Positions  Height(cm)  \
# 0           93.0  93.0  FC Barcelona  2004 - 2021  RW| ST| CF         170
# 1           92.0  92.0      Juventus  2018 - 2022      ST| LW         187
#
#    Weight(kg) Preferred Foot   BOV Best Position     Joined   Value  Wage  \
# 0          72           Left  93.0            RW 2004-07-01  103.5M  560K
# 1          83          Right  92.0            ST 2018-07-10     63M  220K
#
#   Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# ...

# %%
# Rename the columns so they hold the currency sign

# %%
df = df.rename(columns={'Release Clause': '(€)ReleaseClause'})
df = df.rename(columns={'Wage': '(€)Wage'})
df = df.rename(columns={'Value': '(€)value'})

# %%
df.head(2)
# Out:
#          ID               Name                      FullName  \
# 0  158023.0           L. Messi                  Lionel Messi
# 1   20801.0  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality  Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35
#
#    OverallRating   POT          Club     Contract   Positions  Height(cm)  \
# 0           93.0  93.0  FC Barcelona  2004 - 2021  RW| ST| CF         170
# 1           92.0  92.0      Juventus  2018 - 2022      ST| LW         187
#
#    Weight(kg) Preferred Foot   BOV Best Position     Joined (€)value (€)Wage  \
# 0          72           Left  93.0            RW 2004-07-01   103.5M    560K
# 1          83          Right  92.0            ST 2018-07-10      63M    220K
#
#   (€)ReleaseClause  Attacking  Crossing  Finishing  Heading Accuracy  \
# ...

# %%
#Replace the M with its million in numbers
rc=df[df['(€)ReleaseClause'].str.contains('M')]

# %%
r = lambda x: x.replace('M', ' ')

# %%
rc["(€)ReleaseClause"] = rc["(€)ReleaseClause"].apply(r)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\1004926812.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rc["(€)ReleaseClause"] = rc["(€)ReleaseClause"].apply(r)

# %%
rc["(€)ReleaseClause"] = rc["(€)ReleaseClause"].astype('float')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\2078656607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rc["(€)ReleaseClause"] = rc["(€)ReleaseClause"].astype('float')

# %%
rl = lambda x: x * 1000000

# %%
rc["(€)ReleaseClause"] = rc["(€)ReleaseClause"].apply(rl).astype('int')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\1677001339.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rc["(€)ReleaseClause"] = rc["(€)ReleaseClause"].apply(rl).astype('int')

# %%
rc["(€)ReleaseClause"] = rc["(€)ReleaseClause"].astype('str')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\605644542.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rc["(€)ReleaseClause"] = rc["(€)ReleaseClause"].astype('str')

# %%
df.update(rc)

# %%
df["(€)ReleaseClause"]
# Out:
# 0        138400000
# 1         75900000
# 2        159400000
# 3        161000000
# 4        166500000
#            ...
# 18974          70K
# 18975         165K
# 18976         131K
# 18977          88K
# 18978          79K
# Name: (€)ReleaseClause, Length: 18979, dtype: object

# %%
rk = df[df['(€)ReleaseClause'].str.contains('K')]

# %%
rr = lambda x: x.replace('K', ' ')

# %%
rk["(€)ReleaseClause"] = rk["(€)ReleaseClause"].apply(rr)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\3674517142.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rk["(€)ReleaseClause"] = rk["(€)ReleaseClause"].apply(rr)

# %%
rk["(€)ReleaseClause"]
# Out:
# 2129     978
# 2282     949
# 2592     760
# 2607     800
# 2718     600
#          ...
# 18974     70
# 18975    165
# 18976    131
# 18977     88
# 18978     79
# Name: (€)ReleaseClause, Length: 8088, dtype: object

# %%
rk["(€)ReleaseClause"] = rk["(€)ReleaseClause"].astype('float')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\503208071.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rk["(€)ReleaseClause"] = rk["(€)ReleaseClause"].astype('float')

# %%
r3 = lambda x: x * 1000

# %%
rk["(€)ReleaseClause"] = rk["(€)ReleaseClause"].apply(r3)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\3614107877.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rk["(€)ReleaseClause"] = rk["(€)ReleaseClause"].apply(r3)

# %%
rk["(€)ReleaseClause"] = rk["(€)ReleaseClause"].astype('str')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\4288243453.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rk["(€)ReleaseClause"] = rk["(€)ReleaseClause"].astype('str')

# %%
df.update(rk)

# %%
df["(€)ReleaseClause"] = df["(€)ReleaseClause"].astype('float')

# %%
df["(€)ReleaseClause"]
# Out:
# 0        138400000.0
# 1         75900000.0
# 2        159400000.0
# 3        161000000.0
# 4        166500000.0
#             ...
# 18974        70000.0
# 18975       165000.0
# 18976       131000.0
# 18977        88000.0
# 18978        79000.0
# Name: (€)ReleaseClause, Length: 18979, dtype: float64

# %%
wage_k = df[df["(€)Wage"].str.contains('K')]

# %%
offk= lambda x: x.replace('K', ' ')

# %%
wage_k['(€)Wage'] = wage_k['(€)Wage'].apply(offk)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\292357548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wage_k['(€)Wage'] = wage_k['(€)Wage'].apply(offk)

# %%
wage_k['(€)Wage'] = wage_k['(€)Wage'].astype('float')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\4182724900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wage_k['(€)Wage'] = wage_k['(€)Wage'].astype('float')

# %%
kval = lambda x: x * 1000

# %%
wage_k['(€)Wage'] = wage_k['(€)Wage'].apply(kval)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\2882652537.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wage_k['(€)Wage'] = wage_k['(€)Wage'].apply(kval)

# %%
wage_k['(€)Wage'] = wage_k['(€)Wage'].astype('int32')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\2527285938.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wage_k['(€)Wage'] = wage_k['(€)Wage'].astype('int32')

# %%
df.update(wage_k)

# %%
df['(€)Wage']
#= df['(€)Wage'].astype('int')
# Out:
# 0        560000.0
# 1        220000.0
# 2        125000.0
# 3        370000.0
# 4        270000.0
#            ...
# 18974      1000.0
# 18975         500
# 18976         500
# 18977      2000.0
# 18978      1000.0
# Name: (€)Wage, Length: 18979, dtype: object

# %%
df.head(1)
# Out:
#          ID      Name      FullName  \
# 0  158023.0  L. Messi  Lionel Messi
#
#                                            PlayerUrl Nationality   Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  33.0
#
#    OverallRating   POT          Club     Contract   Positions  Height(cm)  \
# 0           93.0  93.0  FC Barcelona  2004 - 2021  RW| ST| CF       170.0
#
#    Weight(kg) Preferred Foot   BOV Best Position     Joined (€)value  \
# 0        72.0           Left  93.0            RW 2004-07-01   103.5M
#
#     (€)Wage  (€)ReleaseClause  Attacking  Crossing  Finishing  \
# 0  560000.0       138400000.0      429.0      85.0       95.0
#
#    Heading Accuracy  Short Passing  Volleys  Skill  Dribbling  Curve  \
# 0              70.0           91.0     88.0  470.0       96.0   93.0
#
#    FK Accuracy  Long Passing  Ball Control  Movement  Acceleration  \
# 0         94.0          91.0          96.0     451.0          91.0
#
# ...

# %%
val_m = df[df["(€)value"].str.contains('M')]

# %%
mlam = lambda x: x.replace('M',' ')

# %%
val_m["(€)value"] = val_m["(€)value"].apply(mlam)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\3197202278.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_m["(€)value"] = val_m["(€)value"].apply(mlam)

# %%
val_m["(€)value"] = val_m["(€)value"].astype('float')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\3797591520.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_m["(€)value"] = val_m["(€)value"].astype('float')

# %%
lam2 = lambda x: x * 1000000

# %%
val_m["(€)value"] = val_m["(€)value"].apply(lam2)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\2156621198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_m["(€)value"] = val_m["(€)value"].apply(lam2)

# %%
val_m["(€)value"] = val_m["(€)value"].astype('string')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\3052665979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_m["(€)value"] = val_m["(€)value"].astype('string')

# %%
df.update(val_m)

# %%
val_k = df[df["(€)value"].str.contains('K')]

# %%
val_k['(€)value'] = val_k['(€)value'].apply(lambda x: x.replace('K'," "))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\3659695794.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_k['(€)value'] = val_k['(€)value'].apply(lambda x: x.replace('K'," "))

# %%
val_k["(€)value"] = val_k["(€)value"].astype('float')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\2512267866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_k["(€)value"] = val_k["(€)value"].astype('float')

# %%
val_k["(€)value"] = val_k["(€)value"].apply(lambda x: x * 1000).astype('str')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1608\3997054997.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_k["(€)value"] = val_k["(€)value"].apply(lambda x: x * 1000).astype('str')

# %%
df.update(val_k)

# %%
df.head()
# Out:
#          ID               Name                      FullName  \
# 0  158023.0           L. Messi                  Lionel Messi
# 1   20801.0  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389.0           J. Oblak                     Jan Oblak
# 3  192985.0       K. De Bruyne               Kevin De Bruyne
# 4  190871.0          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            PlayerUrl Nationality   Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  33.0
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal  35.0
# 2  http://sofifa.com/player/200389/jan-oblak/210006/    Slovenia  27.0
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium  29.0
# 4  http://sofifa.com/player/190871/neymar-da-silv...      Brazil  28.0
#
#    OverallRating   POT                 Club     Contract   Positions  \
# 0           93.0  93.0         FC Barcelona  2004 - 2021  RW| ST| CF
# ...

# %%
df.Age = df.Age.astype('int')
df['Height(cm)'] = df['Height(cm)'].astype('int')
df['Weight(kg)'] = df['Weight(kg)'].astype('int')
df.Hits = df.Hits.astype('int')

# %%
df.head(2)
# Out:
#          ID               Name                      FullName  \
# 0  158023.0           L. Messi                  Lionel Messi
# 1   20801.0  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
#
#                                            PlayerUrl Nationality  Age  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35
#
#    OverallRating   POT          Club     Contract   Positions  Height(cm)  \
# 0           93.0  93.0  FC Barcelona  2004 - 2021  RW| ST| CF         170
# 1           92.0  92.0      Juventus  2018 - 2022      ST| LW         187
#
#    Weight(kg) Preferred Foot   BOV Best Position     Joined     (€)value  \
# 0          72           Left  93.0            RW 2004-07-01  103500000.0
# 1          83          Right  92.0            ST 2018-07-10   63000000.0
#
#     (€)Wage  (€)ReleaseClause  Attacking  Crossing  Finishing  \
# ...

# %%
df.to_csv('Real Fifa Analysis df.csv')
